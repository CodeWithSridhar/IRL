# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeWithSridhar/IRL/blob/main/Uber_Fare_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as pyplot
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/uber_rides_data.xlsx - sample_train.csv")

# %%
df.head()
# Out:
#     ride_id  fare_amount          pickup_datetime  pickup_longitude  \
# 0  24238194          7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1  27835199          7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2  44984355         12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3  25894730          5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4  17610152         16.0  2014-08-28 17:47:00 UTC        -73.925023
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.738354         -73.999512         40.723217                1
# 1        40.728225         -73.994710         40.750325                1
# 2        40.740770         -73.962565         40.772647                1
# 3        40.790844         -73.965316         40.803349                3
# 4        40.744085         -73.973082         40.761247                5

# %%
df.describe()
# Out:
#             ride_id    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967153        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# ...

# %%
df.shape
# Out:
# (200000, 8)

# %%
#integer columns

integer_columns = df.select_dtypes(include=['int']).shape[1]
print(integer_columns)
# Out:
# 2

# %%
#missing values in dropoff

missing_values_dropoff_longitude = df['dropoff_longitude'].isnull().sum()
print(missing_values_dropoff_longitude)
# Out:
# 1

# %%
#data type

print(df['pickup_datetime'].dtype)
# Out:
# object

# %%
# correct syntax to convert pickup_datetime

df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
print(df['pickup_datetime'].dtype)
# Out:
# datetime64[ns, UTC]

# %%
#function to remove null

df.dropna()
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 0       24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1       27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2       44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3       25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4       17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...          ...          ...                       ...               ...
# 199995  42598914          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997  27804658         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998  20259894         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999  11951496         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %%
#average fare amt.

average_fare_amount = df['fare_amount'].mean()
print(average_fare_amount)
# Out:
# 11.359955250000002

# %%
#median haversine distance between pickup and dropoff locatio

import numpy as np

def haversine_distance(lat1, lon1, lat2, lon2):
  """
  Calculates the Haversine distance between two points on a sphere (earth).

  Args:
    lat1: Latitude of the first point in degrees.
    lon1: Longitude of the first point in degrees.
    lat2: Latitude of the second point in degrees.
    lon2: Longitude of the second point in degrees.

  Returns:
    The Haversine distance between the two points in kilometers.
  """

  R = 6371  # Radius of the earth in km

  # Convert latitude and longitude from degrees to radians
  lat1_rad = np.radians(lat1)
  lon1_rad = np.radians(lon1)
  lat2_rad = np.radians(lat2)
  lon2_rad = np.radians(lon2)

  # Difference in latitude and longitude
  dlat = lat2_rad - lat1_rad
  dlon = lon2_rad - lon1_rad

  # Haversine formula
  a = np.sin(dlat / 2)**2 + np.cos(lat1_rad) * np.cos(lat2_rad) * np.sin(dlon / 2)**2
  c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
  distance = R * c

  return distance


# Calculate Haversine distance for each row in the DataFrame
df['haversine_distance'] = df.apply(lambda row: haversine_distance(row['pickup_latitude'], row['pickup_longitude'], row['dropoff_latitude'], row['dropoff_longitude']), axis=1)

# Calculate the median Haversine distance
median_haversine_distance = df['haversine_distance'].median()

print(median_haversine_distance)
# Out:
# 2.1209923961833708

# %%
#maximum haversine distance between pickup and dropoff location

max_haversine_distance = df['haversine_distance'].max()
print(max_haversine_distance)
# Out:
# 16409.239135313168

# %%
#rides have 0.0 haversine distance between pickup and dropoff location

zero_haversine_distance_rides = df[df['haversine_distance'] == 0.0].shape[0]
print(zero_haversine_distance_rides)
# Out:
# 5632

# %%
#mean fare_amount
mean_fare_amount_zero_distance = df[df['haversine_distance'] == 0.0]['fare_amount'].mean()
print(mean_fare_amount_zero_distance)
# Out:
# 11.585317826704546

# %% [markdown]
# It's suspicious that there are rides with a Haversine distance of 0.0
# but a non-zero fare amount.  This suggests that either:
#
#     1. The pickup and drop-off locations were not accurately recorded.
#     2. The rides were very short, potentially within the same building or block,
#     but the recording method couldn't capture a small distance.
#     3. There might be data entry errors.
#
#
# Possible approaches include:
# 1. Visualizing these rides on a map using their pickup and drop-off coordinates.
# 2. Examining the passenger count, ride time, and other related columns for
# these rides to see if there's any pattern.
# 3. Checking the data source and the data collection methodology for
# potential limitations or biases.
#
# It's crucial to handle these cases with care, as they could affect the
# accuracy of any models built on this data.
# You might consider options like:
# 1. Removing the rows with 0.0 Haversine distance as they might not be
# representative of actual rides.
# 2. Imputing the missing values based on factors like ride duration or
# using a proxy for the missing location.
#
# If removing them completely is not preferred, we can assign a small
# Haversine distance or calculate it using different methods.
#
# Expert Opinion:
#
# The existence of rides with 0.0 Haversine distance and a non-zero fare
# amount is a potential issue. This may suggest there might be data quality
# problems, recording issues, or possible errors in the data.
# Before using this data for predictive modeling, it's essential to further
# examine the origin and possible causes of these rides.
# Decisions like removing or treating these cases should be taken carefully
# based on the specific analysis and domain expertise.

# %%
max_fare_amount = df['fare_amount'].max()
print(max_fare_amount)
# Out:
# 499.0

# %%
# row with the maximum fare amount
costliest_ride = df[df['fare_amount'] == df['fare_amount'].max()]

# Extract for the costliest ride
pickup_latitude = costliest_ride['pickup_latitude'].values[0]
pickup_longitude = costliest_ride['pickup_longitude'].values[0]
dropoff_latitude = costliest_ride['dropoff_latitude'].values[0]
dropoff_longitude = costliest_ride['dropoff_longitude'].values[0]

#Haversine distance
haversine_distance_costliest_ride = haversine_distance(pickup_latitude, pickup_longitude, dropoff_latitude, dropoff_longitude)

print("Haversine distance for the costliest ride:", haversine_distance_costliest_ride)
# Out:
# Haversine distance for the costliest ride: 0.0007899213191009993

# %% [markdown]
# It's quite fishy that the costliest ride has a relatively small Haversine distance.
# A large fare amount usually corresponds to a longer trip distance, but in this case,
# it appears that there's a mismatch.
#
# Possible reasons:
# 1. Data Entry Error
# 2. Surge Pricing
# 3. Outlier
# 4. Incorrect Location Data
#
# Further Analysis:
# 1. Verify if the fare amount is within a reasonable range for the
# corresponding distance.
# 2. Investigate if there are any patterns or factors related to the
# costliest rides, such as time of day, day of the week, or specific location.
# 3. Look for outliers in the fare amount column and potentially remove them
# if deemed necessary.
# 4. Review if any particular ride or passenger details could explain the
# large fare amount for a small distance.

# %%
# rides were recorded in2014

# Convert 'pickup_datetime' to datetime objects
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])

# Filter the DataFrame for rides in the year 2014
rides_2014 = df[df['pickup_datetime'].dt.year == 2014]

num_rides_2014 = rides_2014.shape[0]

print(f"The number of rides recorded in 2014 is: {num_rides_2014}")
# Out:
# The number of rides recorded in 2014 is: 29968

# %%
#rides recorded in first quarter of 2014

# Filter the DataFrame for rides in the first quarter
rides_first_quarter_2014 = df[(df['pickup_datetime'].dt.year == 2014) & (df['pickup_datetime'].dt.quarter == 1)]

# Get the number of rides in the first quarter of 2014
num_rides_first_quarter_2014 = rides_first_quarter_2014.shape[0]

print(f"The number of rides recorded in the first quarter of 2014 is: {num_rides_first_quarter_2014}")
# Out:
# The number of rides recorded in the first quarter of 2014 is: 7687

# %%
# day of the week in September 2010, maximum rides were recorded

# Filter the DataFrame for rides in September 2010
rides_september_2010 = df[(df['pickup_datetime'].dt.year == 2010) & (df['pickup_datetime'].dt.month == 9)]

# Extract the day of the week for each ride in September 2010
rides_september_2010['day_of_week'] = rides_september_2010['pickup_datetime'].dt.dayofweek

# Count the number of rides for each day of the week
rides_by_day = rides_september_2010.groupby('day_of_week')['pickup_datetime'].count()

# Find the day with the maximum number of rides
max_rides_day = rides_by_day.idxmax()

# Map the day of the week index to its corresponding name
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_name = days_of_week[max_rides_day]

print(f"The day of the week with the maximum rides in September 2010 is: {day_name}")
# Out:
# The day of the week with the maximum rides in September 2010 is: Thursday

# %% [markdown]
# Que: Apply a Machine Learning Algorithm to predict the fare amount given following input features:
# passenger_count, distance and ride_week_day.
# Perform a 70-30 split of data.
# Which algorithm gives the least adjusted R square value?

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer # import imputer to handle nan values

# Extract relevant features and target variable
features = ['passenger_count', 'haversine_distance']
target = 'fare_amount'
df['ride_week_day'] = df['pickup_datetime'].dt.dayofweek
features.append('ride_week_day')

X = df[features]
y = df[target]

# Split data into training and testing sets (70-30 split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Impute missing values with the mean
imputer = SimpleImputer(strategy='mean') # create an imputer object with strategy as mean
X_train = imputer.fit_transform(X_train) # fit and transform on the train set
X_test = imputer.transform(X_test) # transform the test set

# Scale numerical features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train) # fit and transform on the train set
X_test = scaler.transform(X_test) # transform the test set

# Train different regression models
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree Regression': DecisionTreeRegressor(),
    'Random Forest Regression': RandomForestRegressor()
}

adjusted_r2_scores = {}
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    n = len(y_test)
    p = X_test.shape[1]
    adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)
    adjusted_r2_scores[model_name] = adjusted_r2

# Find the algorithm with the least adjusted R-squared value
min_adjusted_r2_model = min(adjusted_r2_scores, key=adjusted_r2_scores.get)

print("Adjusted R-squared scores:")
for model_name, adjusted_r2 in adjusted_r2_scores.items():
    print(f"{model_name}: {adjusted_r2}")

print(f"\nThe algorithm with the least adjusted R-squared value is: {min_adjusted_r2_model}")
# Out:
# Adjusted R-squared scores:
# Linear Regression: 0.000712532135860644
# Decision Tree Regression: 0.4721556934996487
# Random Forest Regression: 0.6173127262023426
#
# The algorithm with the least adjusted R-squared value is: Linear Regression
